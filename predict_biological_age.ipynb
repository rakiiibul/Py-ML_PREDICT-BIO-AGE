# %% [markdown]
# <center>
#
# # Predict Biological Age
# ## Raikibul Hasan
# Python Machine Learning Project to predict biological age from health data
#
# </center>

# %% [markdown]
# 1.  Importing the required modules
#     I will import the following modules for this Project:
#
#     - `pandas` we will deal the data manipulation and analysis with  this library.
#     - `numpy`
#     - `seaborn`
#     - `matplotlib`
#     - `sklearn.model_selection`
#     - `sklearn.metrics`
#     - `math`
#     - `klearn.linear_model`

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import r2_score 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNC
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Step 2: In this step,We will import and explore our health data

# %% [markdown]
# # 1.Exploration of the variable space of training data

# %%
df1=pd.read_csv(r'training_data.csv')
df1.head()
# Out:
#    Unnamed: 0   age  anaemia  creatinine_phosphokinase  diabetes  \
# 0           0  75.0        0                       582         0
# 1           1  55.0        0                      7861         0
# 2           2  65.0        0                       146         0
# 3           3  50.0        1                       111         0
# 4           4  65.0        1                       160         1
#
#    ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                 20                    1  265000.00               1.9
# 1                 38                    0  263358.03               1.1
# 2                 20                    0  162000.00               1.3
# 3                 20                    0  210000.00               1.9
# 4                 20                    0  327000.00               2.7
#
#    serum_sodium  sex  smoking  time
# 0           130    1        0     4
# 1           136    1        0     6
# ...

# %%
df2=pd.read_csv(r'real_test_data.csv')
df2.head()
# Out:
#    Unnamed: 0  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0           0        0                       383         0                 32
# 1           1        0                       714         0                 42
# 2           2        1                       102         0                 54
# 3           3        0                      1501         1                 48
# 4           4        1                       273         0                 26
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  216756.66              0.89           138    1
# 1                    1  129419.84              2.50           143    1
# 2                    1  257196.98              0.72           138    1
# 3                    1  215230.94              0.90           138    0
# 4                    0  166515.37              1.60           138    0
#
#    smoking  time
# 0        0    99
# 1        1    67
# ...

# %%
df_train = df1.drop(columns=df1.columns[0])
df_train.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time
# 0        0     4
# 1        0     6
# 2        1     7
# 3        0     7
# ...

# %%
df_test = df2.drop(columns=df1.columns[0])
df_test.head()
# Out:
#    anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0        0                       383         0                 32
# 1        0                       714         0                 42
# 2        1                       102         0                 54
# 3        0                      1501         1                 48
# 4        1                       273         0                 26
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  216756.66              0.89           138    1
# 1                    1  129419.84              2.50           143    1
# 2                    1  257196.98              0.72           138    1
# 3                    1  215230.94              0.90           138    0
# 4                    0  166515.37              1.60           138    0
#
#    smoking  time
# 0        0    99
# 1        1    67
# 2        1   187
# 3        1    67
# 4        0   211

# %% [markdown]
# # Checking for the missing data

# %%
df_train.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# dtype: int64
